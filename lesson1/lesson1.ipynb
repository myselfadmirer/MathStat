# %% [markdown]
# ## 1. Из колоды в 52 карты извлекаются случайным образом 4 карты.

# %% [markdown]
# ### a) Найти вероятность того, что все карты – крести.

# %% [markdown]
# ### $P=\frac m{n}$
# ### $n=C^4_{52}=\frac{52!}{4!(52-4)!}=270725$
# ### $m=C^4_{13}=\frac{13!}{4!(13-4)!}=715$
# ### $P=\frac{715}{270725}=0,0026$

# %% [markdown]
# ### б) Найти вероятность, что среди 4-х карт окажется хотя бы один туз.

# %% [markdown]
# ### $P=\frac m{n}$
# ### или $P=1-\frac m{n}$, если примем за событие отсутствие тузов вовсе, так как только этот вариант не подходит.
# ### $n=C^4_{52}=\frac{52!}{4!(52-4)!}=270725$
# ### $m=C^4_{48}=\frac{48!}{4!(48-4)!}=194580$
# ### $P=1-\frac{194580}{270725}=0,28$

# %% [markdown]
# ## 2. На входной двери подъезда установлен кодовый замок, содержащий десять кнопок с цифрами от 0 до 9. Код содержит три цифры, которые нужно нажать одновременно. Какова вероятность того, что человек, не знающий код, откроет дверь с первой попытки?

# %% [markdown]
# ### Имеем 10 цифр, из которых нужно выбрать 3, цифры не повторяются, так как их нужно нажать одновременно.
# ### Следовательно,
# ### $P=\frac m{n}$
# ### $n=C^3_{10}=\frac{10!}{3!(7)!}=120$
# ### Так как попытка только 1, $m=1$
# ### $P=\frac{1}{120}=0,0083$

# %% [markdown]
# ## 3. В ящике имеется 15 деталей, из которых 9 окрашены. Рабочий случайным образом извлекает 3 детали. Какова вероятность того, что все извлеченные детали окрашены?

# %% [markdown]
# ### $P=\frac m{n}$
# ### $n=C^3_{15}=\frac{15!}{3!12!}=455$
# ### $m=C^3_{9}=\frac{9!}{3!6!}=84$
# ### $P=\frac{84}{455}=0,185$

# %% [markdown]
# ## 4. В лотерее 100 билетов. Из них 2 выигрышных. Какова вероятность того, что 2 приобретенных билета окажутся выигрышными?

# %% [markdown]
# ### $P=\frac m{n}$
# ### $n=C^2_{100}=\frac{100!}{2!98!}=4950$
# ### $m=C^2_{2}=1$
# ### $P=\frac{1}{4950}=0,0002$
